# %%
# check if GPU is available (optional if time is not a constraint)
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# install conda
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:36
# 🔁 Restarting kernel...

# %%
# check conda
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# install required packages
# !conda env update -n base -f env.yml
# Out:
# done
# \ WARNING conda.core.solve:_add_specs(611): pinned spec python=3.7 conflicts with explicit specs.  Overriding pinned spec.
# failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==5.1=1_gnu
#     - blas==1.0=mkl
#     - brotli==1.0.9=he6710b0_2
#     - bzip2==1.0.8=h7b6447c_0
#     - ca-certificates==2022.07.19=h06a4308_0
#     - conda-forge/linux-64::krb5==1.17.2=h926e7f8_0
#     - conda-forge/linux-64::libcurl==7.75.0=hc4aaa36_0
#     - conda-forge/linux-64::libnghttp2==1.43.0=h812cca2_0
#     - conda-forge/linux-64::libsolv==0.7.17=h780b84a_0
#     - conda==4.9.2
#     - cycler==0.11.0=pyhd3eb1b0_0
#     - dbus==1.13.18=hb2f20db_0
#     - expat==2.4.4=h295c915_0
#     - fontconfig==2.13.1=h6c09931_0
#     - fonttools==4.25.0=pyhd3eb1b0_0
#     - freetype==2.11.0=h70c0345_0
#     - giflib==5.2.1=h7b6447c_0
#     - glib==2.69.1=h4ff587b_1
# ...

# %%
# create required folder structure and download MNIST data set
import os 
import requests
#
os.makedirs('data/mnist')
#
urls = ['http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz',
        'http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz',
        'http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz',
        'http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz']
for i in range(len(urls)):
  response = requests.get(urls[i])
  open('data/mnist/'+urls[i].split('/')[-1], "wb").write(response.content)
#
print('Finished downloading MNIST')
# Out:
# Finished downloading MNIST

# %%
# train and analyze VAE
# %run -i 'vae.py'
# Out:
# Network architecture:
# VAE(
#   (encoder): Encoder(
#     (fc3): Linear(in_features=784, out_features=500, bias=True)
#     (fc4): Linear(in_features=500, out_features=10, bias=True)
#     (fc5): Linear(in_features=500, out_features=10, bias=True)
#   )
#   (decoder): Decoder(
#     (fc1): Linear(in_features=10, out_features=500, bias=True)
#     (fc2): Linear(in_features=500, out_features=784, bias=True)
#   )
# )
# Number of parameters:
# 	10
# Parameter dimensions:
# 	01:	500x784
# 	02:	500
# 	03:	10x500
# 	04:	10
# 	05:	10x500
# 	06:	10
# 	07:	500x10
# 	08:	500
# 	09:	784x500
# 	10:	784
#
# Training VAE:
#
# iteration:	0000000 / 0093750
# loss:			5.93e+03
# lr:			1.00e-02
# train size:	0060000
# batch size:	0000032
# ratio:			0001875
# iteration:	0018750 / 0093750
# loss:			1.04e+03
# lr:			1.00e-02
# train size:	0060000
# batch size:	0000032
# ratio:			0001875
# iteration:	0037500 / 0093750
# loss:			1.22e+03
# lr:			1.00e-02
# train size:	0060000
# batch size:	0000032
# ...
